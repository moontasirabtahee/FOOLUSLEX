# %%
# !apt-get update -y && apt-get install python3.10 python3.10-venv -y
# %cd /content
# !python3.10 -m venv --system-site-packages /content/fooocus_env
# !git clone https://github.com/moontasirabtahee/FOOLUSLEX.git
# %cd /content/FOOLUSLEX
# !/content/fooocus_env/bin/pip install -r requirements_versions.txt
# !/content/fooocus_env/bin/python entry_with_update.py --share --preset realistic --always-high-vram
