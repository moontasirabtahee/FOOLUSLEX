# %%
# Step 1: Install Python 3.10, create environment, and clone repository
# !apt-get update -y && apt-get install python3.10 python3.10-venv -y
# %cd /content
# !rm -rf /content/FOOLUSLEX
# !python3.10 -m venv --system-site-packages /content/fooocus_env
# !/content/fooocus_env/bin/pip install --upgrade pip
# !git clone https://github.com/moontasirabtahee/FOOLUSLEX.git
# %cd /content/FOOLUSLEX
# !/content/fooocus_env/bin/pip install -r requirements_versions.txt
# !/content/fooocus_env/bin/pip install huggingface_hub

# %%
# Step 2: Set Hugging Face Token (Required to download private LoRA models)
import os
from getpass import getpass
# Enter your HuggingFace User Access Token (from https://huggingface.co/settings/tokens)
hf_token = getpass("Enter your Hugging Face Token: ").strip()
if hf_token:
    os.environ["HF_TOKEN"] = hf_token
    # !/content/fooocus_env/bin/huggingface-cli login --token {hf_token}
    print("Hugging Face Token successfully configured!")

# %%
# Step 3: Launch Fooocus with realistic preset (Auto downloads Lustify v2.0 + Face & Body LoRAs)
# %cd /content/FOOLUSLEX
# !/content/fooocus_env/bin/python entry_with_update.py --share --preset realistic --always-high-vram
